# %%
import pandas as pd

# %%
df = pd.read_csv('insurance_data.csv')
df
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %%
df = df.drop(columns=['index', 'PatientID'])
df
# Out:
#        age  gender   bmi  bloodpressure diabetic  children smoker     region  \
# 0     39.0    male  23.2             91      Yes         0     No  southeast
# 1     24.0    male  30.1             87       No         0     No  southeast
# 2      NaN    male  33.3             82      Yes         0     No  southeast
# 3      NaN    male  33.7             80       No         0     No  northwest
# 4      NaN    male  34.1            100       No         0     No  northwest
# ...    ...     ...   ...            ...      ...       ...    ...        ...
# 1335  44.0  female  35.5             88      Yes         0    Yes  northwest
# 1336  59.0  female  38.1            120       No         1    Yes  northeast
# 1337  30.0    male  34.5             91      Yes         3    Yes  northwest
# 1338  37.0    male  30.4            106       No         0    Yes  southeast
# 1339  30.0  female  47.4            101       No         0    Yes  southeast
#
#          claim
# 0      1121.87
# ...

# %%
import matplotlib.pyplot as plt

plt.figure()
df.boxplot(['age'])
# Out:
# <AxesSubplot:>

# %%
plt.figure()
df.boxplot(['bmi'])
# Out:
# <AxesSubplot:>

# %%
plt.figure()
df.boxplot(['bloodpressure'])
# Out:
# <AxesSubplot:>

# %%
plt.figure()
df.boxplot(['children'])
# Out:
# <AxesSubplot:>

# %%
plt.figure()
df.boxplot(['claim'])
# Out:
# <AxesSubplot:>

# %%
gender_counts = df['gender'].value_counts()

plt.figure(figsize=(8, 8)) 
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Gender Distribution')

plt.show()

# %%
diabetic_counts = df['diabetic'].value_counts()

plt.figure(figsize=(8, 8)) 
plt.pie(diabetic_counts, labels=diabetic_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Diabetic Distribution')

plt.show()

# %%
smoker_count = df['smoker'].value_counts()

plt.figure(figsize=(8, 8)) 
plt.pie(smoker_count, labels=smoker_count.index, autopct='%1.1f%%', startangle=90)
plt.title('Smoker Distribution')

plt.show()

# %%
region_count = df['region'].value_counts()

plt.figure(figsize=(8, 8)) 
plt.pie(region_count, labels=region_count.index, autopct='%1.1f%%', startangle=90)
plt.title('Region Distribution')

plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            1335 non-null   float64
#  1   gender         1340 non-null   object
#  2   bmi            1340 non-null   float64
#  3   bloodpressure  1340 non-null   int64
#  4   diabetic       1340 non-null   object
#  5   children       1340 non-null   int64
#  6   smoker         1340 non-null   object
#  7   region         1337 non-null   object
#  8   claim          1340 non-null   float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 94.3+ KB

# %%
df.describe()
# Out:
#                age          bmi  bloodpressure     children         claim
# count  1335.000000  1340.000000    1340.000000  1340.000000   1340.000000
# mean     38.078652    30.668955      94.157463     1.093284  13252.745642
# std      11.102924     6.106735      11.434712     1.205334  12109.609288
# min      18.000000    16.000000      80.000000     0.000000   1121.870000
# 25%      29.000000    26.275000      86.000000     0.000000   4719.685000
# 50%      38.000000    30.400000      92.000000     1.000000   9369.615000
# 75%      47.000000    34.700000      99.000000     2.000000  16604.305000
# max      60.000000    53.100000     140.000000     5.000000  63770.430000

# %%
null_percentage = (df.isnull().sum() / len(df)) * 100
print(null_percentage)
# Out:
# age              0.373134
# gender           0.000000
# bmi              0.000000
# bloodpressure    0.000000
# diabetic         0.000000
# children         0.000000
# smoker           0.000000
# region           0.223881
# claim            0.000000
# dtype: float64

# %%
# extremely small amount of null values, drop them 
df = df.dropna()
df
# Out:
#        age  gender   bmi  bloodpressure diabetic  children smoker     region  \
# 0     39.0    male  23.2             91      Yes         0     No  southeast
# 1     24.0    male  30.1             87       No         0     No  southeast
# 7     19.0    male  41.1            100       No         0     No  northwest
# 8     20.0    male  43.0             86       No         0     No  northwest
# 9     30.0    male  53.1             97       No         0     No  northwest
# ...    ...     ...   ...            ...      ...       ...    ...        ...
# 1335  44.0  female  35.5             88      Yes         0    Yes  northwest
# 1336  59.0  female  38.1            120       No         1    Yes  northeast
# 1337  30.0    male  34.5             91      Yes         3    Yes  northwest
# 1338  37.0    male  30.4            106       No         0    Yes  southeast
# 1339  30.0  female  47.4            101       No         0    Yes  southeast
#
#          claim
# 0      1121.87
# ...

# %%
null_percentage = (df.isnull().sum() / len(df)) * 100
print(null_percentage)
# Out:
# age              0.0
# gender           0.0
# bmi              0.0
# bloodpressure    0.0
# diabetic         0.0
# children         0.0
# smoker           0.0
# region           0.0
# claim            0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1332 entries, 0 to 1339
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            1332 non-null   float64
#  1   gender         1332 non-null   object
#  2   bmi            1332 non-null   float64
#  3   bloodpressure  1332 non-null   int64
#  4   diabetic       1332 non-null   object
#  5   children       1332 non-null   int64
#  6   smoker         1332 non-null   object
#  7   region         1332 non-null   object
#  8   claim          1332 non-null   float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 104.1+ KB

# %%
df.describe()
# Out:
#                age          bmi  bloodpressure     children         claim
# count  1332.000000  1332.000000    1332.000000  1332.000000   1332.000000
# mean     38.086336    30.658333      94.189189     1.099850  13325.246426
# std      11.112804     6.118967      11.445173     1.205958  12109.620712
# min      18.000000    16.000000      80.000000     0.000000   1121.870000
# 25%      29.000000    26.200000      86.000000     0.000000   4760.157500
# 50%      38.000000    30.350000      92.000000     1.000000   9412.965000
# 75%      47.000000    34.725000      99.000000     2.000000  16781.327500
# max      60.000000    53.100000     140.000000     5.000000  63770.430000

# %%
# change to numeric value for correlation
#df.replace('male', 0, inplace=True)
#df.replace('female', 1, inplace=True)
#df

# %%
df.replace('male', '0', inplace=True)
df.replace('female', '1', inplace=True)
df['diabetic'].replace('No', '0', inplace=True)
df['diabetic'].replace('Yes', '1', inplace=True)
df['smoker'].replace('No', '0', inplace=True)
df['smoker'].replace('Yes', '1', inplace=True)

df['region'].replace('northeast', '0', inplace=True)
df['region'].replace('southeast', '1', inplace=True)
df['region'].replace('southwest', '2', inplace=True)
df['region'].replace('northwest', '3', inplace=True)
df

# %%
df.corr()
# Out:
#                     age    gender       bmi  bloodpressure  diabetic  \
# age            1.000000  0.393452 -0.042152      -0.060322 -0.026246
# gender         0.393452  1.000000 -0.045271      -0.015256  0.019277
# bmi           -0.042152 -0.045271  1.000000       0.144977 -0.038099
# bloodpressure -0.060322 -0.015256  0.144977       1.000000 -0.010183
# diabetic      -0.026246  0.019277 -0.038099      -0.010183  1.000000
# children      -0.026208 -0.021300  0.013719      -0.034356 -0.013221
# smoker        -0.032211 -0.078666  0.004560       0.418049  0.018462
# region        -0.021744 -0.008812 -0.077887      -0.075619 -0.052348
# claim         -0.028636 -0.062052  0.199945       0.531263 -0.007020
#
#                children    smoker    region     claim
# age           -0.026208 -0.032211 -0.021744 -0.028636
# gender        -0.021300 -0.078666 -0.008812 -0.062052
# bmi            0.013719  0.004560 -0.077887  0.199945
# bloodpressure -0.034356  0.418049 -0.075619  0.531263
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df.corr()

plt.figure(figsize=(8, 6)) 
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
df = df.astype(float)

# %%
import pandas as pd
import statsmodels.api as sm

X = df[['age', 'gender', 'bmi', 'bloodpressure', 'diabetic', 'children', 'smoker', 'region']]
Y = df['claim']


X = sm.add_constant(X)


model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  claim   R-squared:                       0.701
# Model:                            OLS   Adj. R-squared:                  0.700
# Method:                 Least Squares   F-statistic:                     388.6
# Date:                Tue, 05 Sep 2023   Prob (F-statistic):               0.00
# Time:                        17:30:34   Log-Likelihood:                -13608.
# No. Observations:                1332   AIC:                         2.723e+04
# Df Residuals:                    1323   BIC:                         2.728e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -2.324e+04   1979.483    -11.740      0.000   -2.71e+04   -1.94e+04
# ...
